# %%
#Scatter plots

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
body_data = pd.read_csv("weights_and_heights.csv")

#Split data frames
male = body_data[body_data["Gender"] == "Male"]
female = body_data[body_data["Gender"] == "Female"]

# %%
male_sample = male.sample(200, random_state = 42) #Random 200 sample, 42 means multiple people should get same randomly selected rows

# %%
male_sample
# Out:
#      Gender     Height      Weight
# 1501   Male  71.970526  211.542785
# 2586   Male  69.130038  179.006333
# 2653   Male  67.894777  178.177298
# 1055   Male  70.887487  182.887948
# 705    Male  67.121503  167.191527
# ...     ...        ...         ...
# 1096   Male  75.999957  224.440459
# 829    Male  69.838657  178.392483
# 2805   Male  71.892218  199.829699
# 3829   Male  72.758054  211.749664
# 4381   Male  69.699604  182.700814
#
# [200 rows x 3 columns]

# %%
male_sample.shape
# Out:
# (200, 3)

# %%
plt.style.use("seaborn-poster")
plt.scatter(male_sample["Weight"], male_sample["Height"], color = "blue", s = 700, alpha = 0.5) #s= size of data points, alpha = transparency of data points
plt.title("Weight vs Height for Males")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (in)")
plt.tight_layout()
plt.show()
#Strong relationship between weight (X) and height (Y)
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\3932593351.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#What if we want to show where median are?
#At V line and at H line 
plt.style.use("seaborn-poster")
plt.scatter(male_sample["Weight"], male_sample["Height"], color = "blue", s = 700, alpha = 0.5) #s= size of data points, alpha = transparency of data points
plt.title("Weight vs Height for Males")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (in)")

plt.axvline(x = male_sample["Weight"].median(), color = "black", linestyle = "--" ) #Median
plt.axhline(y = male_sample["Height"].median(), color = "black", linestyle = "--" ) #Median
plt.tight_layout()
plt.show()
#Strong relationship between weight (X) and height (Y)
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\3383338410.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#We want to show the patient on the plot here.

male_sample
# Out:
#      Gender     Height      Weight
# 1501   Male  71.970526  211.542785
# 2586   Male  69.130038  179.006333
# 2653   Male  67.894777  178.177298
# 1055   Male  70.887487  182.887948
# 705    Male  67.121503  167.191527
# ...     ...        ...         ...
# 1096   Male  75.999957  224.440459
# 829    Male  69.838657  178.392483
# 2805   Male  71.892218  199.829699
# 3829   Male  72.758054  211.749664
# 4381   Male  69.699604  182.700814
#
# [200 rows x 3 columns]

# %%
#We can pick patient #705 
patient = male_sample.loc[[705]]

# %%
patient
# Out:
#     Gender     Height      Weight
# 705   Male  67.121503  167.191527

# %%
#Let's highlight the data point here
plt.style.use("seaborn-poster")
plt.scatter(male_sample["Weight"], male_sample["Height"], color = "blue", s = 700, alpha = 0.5) #s= size of data points, alpha = transparency of data points
plt.scatter(patient["Weight"], patient["Height"], color = "red", s = 700, alpha = 1.0, edgecolor = "pink", linewidth = 2) #New data point
plt.title("Weight vs Height for Males")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (in)")

plt.axvline(x = male_sample["Weight"].median(), color = "black", linestyle = "--" ) #Median
plt.axhline(y = male_sample["Height"].median(), color = "black", linestyle = "--" ) #Median
plt.tight_layout()
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\1411922381.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")

# %%
#Let's highlight the data point here
plt.style.use("seaborn-poster")
plt.scatter(male_sample["Weight"], male_sample["Height"], color = "blue", s = 700, alpha = 0.5) #s= size of data points, alpha = transparency of data points
plt.scatter(patient["Weight"], patient["Height"], marker = "x", color = "red", s = 700, alpha = 1.0, edgecolor = "pink", linewidth = 5) #New data point
plt.title("Weight vs Height for Males")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (in)")

plt.axvline(x = male_sample["Weight"].median(), color = "black", linestyle = "--" ) #Median
plt.axhline(y = male_sample["Height"].median(), color = "black", linestyle = "--" ) #Median
plt.tight_layout()
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\1606211194.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\1606211194.py:4: UserWarning: You passed a edgecolor/edgecolors ('pink') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(patient["Weight"], patient["Height"], marker = "x", color = "red", s = 700, alpha = 1.0, edgecolor = "pink", linewidth = 5) #New data point

# %%
#Use circle and x to highlight datapoint
plt.style.use("seaborn-poster")
plt.scatter(male_sample["Weight"], male_sample["Height"], color = "blue", s = 700, alpha = 0.5) #s= size of data points, alpha = transparency of data points
plt.scatter(patient["Weight"], patient["Height"], color = "pink", s = 700, alpha = 1.0, edgecolor = "red", linewidth = 5) #New data point
plt.scatter(patient["Weight"], patient["Height"], marker = "x", color = "red", s = 250, alpha = 1.0, edgecolor = "pink", linewidth = 5) #New data point
plt.title("Weight vs Height for Males")
plt.xlabel("Weight (lbs)")
plt.ylabel("Height (in)")

plt.axvline(x = male_sample["Weight"].median(), color = "black", linestyle = "--" ) #Median
plt.axhline(y = male_sample["Height"].median(), color = "black", linestyle = "--" ) #Median
plt.tight_layout()
plt.show()
# Out:
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\3062854910.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-poster")
# C:\Users\19144\AppData\Local\Temp\ipykernel_1960\3062854910.py:5: UserWarning: You passed a edgecolor/edgecolors ('pink') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(patient["Weight"], patient["Height"], marker = "x", color = "red", s = 250, alpha = 1.0, edgecolor = "pink", linewidth = 5) #New data point
